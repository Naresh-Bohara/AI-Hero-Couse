# %% [markdown]
# # Lab 1.3 – Input & Output:

# %% [markdown]
# ### q1. Write a Python script that:
# - Asks for your name
# - Prints: Hello, name

# %%
name = input("Please enter your name: ")
print(f"Hello, {name}")
# Out:
# Please enter your name:  Naresh
# Hello, Naresh

# %% [markdown]
# ### q2. Ask the user:
# “How old are you?”
# Convert the input to an integer
# Print: Next year you will be <age + 1>

# %%
age_str = input("How old are you? ")
age_int = int(age_str)
print(f"Next year you will be {age_int+1}")
# Out:
# How old are you?  23
# Next year you will be 24

# %% [markdown]
# ### q3. Ask for:
# Name,
# Age
# Print using f-string:
# Welcome, name! You are age years old.

# %%
name = input("Please enter your Name: ")
age  = int(input("Enter your age: "))
print(f"Welcome! {name}, You are {age} years old")
# Out:
# Please enter your Name:  naresh
# Enter your age:  23
# Welcome! naresh, You are 23 years old

# %% [markdown]
# ### q4. Print the same sentence using .format() instead of f-string.

# %%
name = input("Please enter your Name: ")
age  = int(input("Enter your age: "))
print("Welcome {0}! you are {1} years old. ".format(name, age))
# Out:
# Please enter your Name:  nari
# Enter your age:  34
# Welcome nari! you are 34 years old.

# %% [markdown]
# ### q5. Mini Exercise:
# Ask for first name
# Ask for last name
# Combine them with a space
# Print:
# Nice to meet you, <FirstName <LastName!

# %%
fname = input("Please enter first name: ")
lname = input("Please enter last name: ")
print(f"Nice to meet you, {fname} {lname}!")
# Out:
# Please enter first name:  nari
# Please enter last name:  bohara
# Nice to meet you, nari bohara!

# %% [markdown]
# #### 1. What type does input() always return?
# -> input() always returns string
# #### 2. why do we need to convert age with int()?
# -> Because inptu() always gives a string, and we must need to convert age to int to perform any mathematical operations on it.
# #### 3. which formatting do you prefer - f-strings or .format()?
# -> I prefer f-strings, because they are cleaner, easier and more readable.
