# %%
print("👋 Welcome to Lab 1.1! You're running Python in a Jupyter Notebook.")
# Out:
# 👋 Welcome to Lab 1.1! You're running Python in a Jupyter Notebook.

# %%
a = 50
b = 4
add = a + b
print(add)
# Out:
# 54

# %% [markdown]
# ## Arithmetic operations:

# %%
a = 20
b = 3
add =  a + b
sub = a - b
mul = a * b
div = a / b
floor_div = a // b
mod = a % b
power = a ** b
print(f"add = {add}, sub={sub}, mul = {mul}, div={div}, floor_div={floor_div}, mod={mod}, power = {power} ")
# Out:
# add = 23, sub=17, mul = 60, div=6.666666666666667, floor_div=6, mod=2, power = 8000

# %% [markdown]
# ## Taking input from user:

# %%
name = input("Enter your name: ")
print("Hello", name)
# Out:
# Enter your name:  heery
# Hello heery

# %%
print(type(a))
print(type(div))
print(type(3.3))
print(type("hello"))
print(sum([1, 2, 3, 4, 5]))
print(round(3.14159, 3))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'float'>
# <class 'str'>
# 15
# 3.142

# %% [markdown]
# ## What I Learned:
# - How to create and run a Jupyter notebook
# - How to print text and perform arithmetic
# - The difference between /, //, %, and **
